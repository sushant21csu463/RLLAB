# %% [markdown]
# <a href="https://colab.research.google.com/github/sushant21csu463/RLLAB/blob/main/UCB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

num_arms = 5

means = np.random.normal(0, 1, num_arms)

totalSteps = 1000
num_selections = np.zeros(num_arms)
sum_rewards = np.zeros(num_arms)
ucb_rewards = []

for t in range(1, totalSteps + 1):
    arm_to_pull_ucb = np.argmax(sum_rewards / (num_selections + 1e-6)
    + np.sqrt(2 * np.log(t) / (num_selections + 1e-6)))
    reward_ucb = np.random.normal(means[arm_to_pull_ucb], 1)
    sum_rewards[arm_to_pull_ucb] += reward_ucb
    num_selections[arm_to_pull_ucb] += 1
    ucb_rewards.append(reward_ucb)

cumulative_ucb_rewards = np.cumsum(ucb_rewards)

plt.plot(range(1, totalSteps + 1), cumulative_ucb_rewards, label='UCB Algorithm')

plt.xlabel('Iterations')
plt.ylabel('Cumulative Reward')
plt.legend()
plt.title('Multi-Armed Bandit: UCB')
plt.show()
print(num_selections)
print(sum_rewards)
print(ucb_rewards)
# Out:
# [ 11. 622.  12. 351.   4.]
# [ -9.04214268 174.56073986  -9.1331383   78.66103268  -6.97995525]
# ...
